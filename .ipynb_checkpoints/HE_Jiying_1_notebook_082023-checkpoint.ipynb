# %%
import pandas as pd
import numpy as np
import warnings 
import nltk
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras import layers, models, datasets
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from skimage import exposure
from scipy.ndimage import median_filter
import os
import shutil
import random
import splitfolders
from shutil import copyfile
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from keras.layers import Flatten, Dense, Activation, Add
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import kerastuner as kt
from tensorflow.keras.optimizers import Adam, RMSprop
import datetime, time

# %%
warnings.filterwarnings('ignore')

# %%
def remove_all_files_and_directories(directory):
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"The directory '{directory}' does not exist.")
        return

    # Remove all files in the directory
    for root, dirs, files in os.walk(directory, topdown=False):
        for file in files:
            file_path = os.path.join(root, file)
            os.remove(file_path)

    # Remove all subdirectories in the directory
    for root, dirs, files in os.walk(directory, topdown=False):
        for dir in dirs:
            dir_path = os.path.join(root, dir)
            shutil.rmtree(dir_path)

    # Remove the top-level directory itself
    os.rmdir(directory)

# %% [markdown]
# # 1. Chargement et prétraitement des images

# %% [markdown]
# ## 1.1 Prétraitement d'image

# %% [raw]
# le prétraitement d'images est essentiel pour préparer les images avant de les utiliser comme entrées pour les modèles d'apprentissage automatique. Il permet d'améliorer la qualité des images, d'augmenter la taille de l'ensemble de données, de réduire la complexité et de rendre les images plus adaptées aux besoins spécifiques du modèle.

# %%
# Function de prétraitement d'images
def pretraitement_image(img):    
    
    # 2) auto Contraste: ajuster automatiquement le contraste d'une image pour étendre 
    # la gamme de valeurs de pixel sur toute l'échelle des couleurs. (hist plus large)

    # Calculer les valeurs minimales et maximales des pixels de l'image
    min_value = tf.reduce_min(img)
    max_value = tf.reduce_max(img)
    # Appliquer la transformation linéaire pour ajuster automatiquement le contraste
    img = (img - min_value) * (255.0 / (max_value - min_value))
    # Convertir les valeurs des pixels en type uint8 (entiers non signés sur 8 bits)
    img = tf.cast(img, tf.uint8)
    
    # 3) Equalization :améliorer la répartition des intensités de pixels dans une image (hist plus plat)
#    img = exposure.equalize_hist(img)
    img = tfa.image.equalize(img)

    # 4) Débruitage (ajouter du bruit gaussien et supprimer le bruit par filtrage)
    img = img + 0.1 * np.random.randn(*img.shape)
    img = median_filter(img, size=(3, 3, 3))

    # 1) Whitening (blanchiment) : Normalisation des valeurs de pixels avec centarge et la mise en echelle
    img = (img - np.mean(img)) / np.std(img)
    return img

# %% [markdown]
# Un example de pretraitement d'image

# %%
# Charger une image (vous pouvez remplacer cette étape par le chargement de votre propre image)
image_path = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/Images/n02086079-Pekinese/n02086079_606.jpg"
image = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
image = tf.keras.preprocessing.image.img_to_array(image)

# Cropping
cropped_image = image[50:150, 50:150]

# Whitening (blanchiment)
whitened_image = (image - np.mean(image)) / np.std(image)

# Contraste
# Calculer les valeurs minimales et maximales des pixels de l'image
min_value = tf.reduce_min(image)
max_value = tf.reduce_max(image)

# Appliquer la transformation linéaire pour ajuster automatiquement le contraste
autocontrasted_image = (image - min_value) * (255.0 / (max_value - min_value))

# Convertir les valeurs des pixels en type uint8 (entiers non signés sur 8 bits)
autocontrasted_image = tf.cast(autocontrasted_image, tf.uint8)

contrast_factor = 1.5
contrasted_image = tf.image.adjust_contrast(image, contrast_factor)
# Égalisation : améliorer la répartition des intensités de pixels dans une image

equalized_image = tfa.image.equalize(image)

# Débruitage (ajouter du bruit gaussien et supprimer le bruit par filtrage)
noisy_image = image + 0.1 * np.random.randn(*image.shape)
denoised_image = median_filter(noisy_image, size=(3, 3, 3))

# Redimensionnement
processed_image = pretraitement_image(image)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Créer une figure avec 3x4 sous-tracés (3 lignes et 4 colonnes)
fig, axes = plt.subplots(3, 4, figsize=(15, 10))

# Afficher les images sur les sous-tracés
axes[0, 0].imshow(image.astype(np.uint8))
axes[0, 0].set_title("Image originale")

# Afficher les histogrammes des images
axes[0, 1].hist(image.flatten(), bins=256, color='r', alpha=0.5)
axes[0, 1].set_title("Histogramme  originale")

axes[0, 2].imshow(autocontrasted_image.numpy().astype(np.uint8))
axes[0, 2].set_title("Image auto contraste")

# Afficher les histogrammes des images
axes[0, 3].hist(autocontrasted_image.numpy().flatten(), bins=256, color='r', alpha=0.5)
axes[0, 3].set_title("Histogramme auto contraste")

axes[1, 0].imshow(whitened_image.astype(np.uint8))
axes[1, 0].set_title("Image blanchi")

# Afficher les histogrammes des images
axes[1, 1].hist(whitened_image.flatten(), bins=256, color='r', alpha=0.5)
axes[1, 1].set_title("Histogramme blanchi")

axes[1, 2].imshow(tf.cast(equalized_image, tf.uint8).numpy())
axes[1, 2].set_title("Image égalisée")

# Afficher les histogrammes des images
axes[1, 3].hist(equalized_image.numpy().flatten(), bins=256, color='r', alpha=0.5)
axes[1, 3].set_title("Histogramme equalisé")

axes[2, 0].imshow(denoised_image.astype(np.uint8))
axes[2, 0].set_title("Image débruitée")

axes[2, 1].hist(denoised_image.flatten(), bins=256, color='r', alpha=0.5)
axes[2, 1].set_title("Histogramme débruité")

axes[2, 2].imshow(processed_image.astype(np.uint8))
axes[2, 2].set_title("Image processed")

axes[2, 3].hist(processed_image.flatten(), bins=256, color='r', alpha=0.5)
axes[2, 3].set_title("Histogramme processed")


# Afficher les titres des sous-tracés
for ax in axes.flat:
    ax.axis("off")

# Ajuster les espacements entre les sous-tracés
plt.tight_layout()

# Afficher la figure
plt.show()

# %% [markdown]
# ## 1.2 Augmentation d'image pour les entrainements

# %% [raw]
# La data augmentation permet d'augmenter la taille de l'ensemble de données d'entraînement en appliquant des transformations aléatoires et réalistes aux images existantes. Voici quelques-uns des principaux avantages de la data augmentation :
#
# Augmentation de la taille de l'ensemble de données : En appliquant des transformations aléatoires aux images existantes, la data augmentation génère de nouvelles images qui sont différentes des images originales, mais toujours liées au même objet ou concept. Cela permet d'augmenter la taille de l'ensemble de données d'entraînement, ce qui est essentiel lorsque l'ensemble de données initial est petit.
#
# Amélioration de la généralisation : En exposant le modèle à une plus grande variabilité d'images, la data augmentation aide à améliorer la généralisation du modèle. Le modèle apprend à reconnaître les caractéristiques importantes des objets plutôt que de se fier uniquement aux caractéristiques spécifiques présentes dans l'ensemble de données initial.
#
# Réduction du surapprentissage : Le surapprentissage se produit lorsque le modèle apprend trop spécifiquement les images d'entraînement et ne généralise pas bien sur de nouvelles données. La data augmentation introduit de la variabilité dans l'ensemble de données d'entraînement, ce qui peut aider à réduire le surapprentissage en forçant le modèle à généraliser davantage.
#
# Adaptation à différentes conditions d'éclairage et de pose : En appliquant des transformations telles que la rotation, le recadrage, le zoom et le renversement, la data augmentation permet au modèle de s'adapter à différentes conditions d'éclairage et de pose, ce qui rend le modèle plus robuste dans des environnements réels.

# %%
# Définir les transformations de data augmentation
train_data_augmentation = ImageDataGenerator(
    rotation_range=20,  # Angle de rotation aléatoire
    width_shift_range=0.2,  # Décalage horizontal aléatoire
    height_shift_range=0.2,  # Décalage vertical aléatoire
    shear_range=0.2,  # Déformation de cisaillement aléatoire
    zoom_range=0.2,  # Zoom aléatoire
    horizontal_flip=True,  # Retournement horizontal aléatoire
    vertical_flip=False,  # Retournement vertical aléatoire
    preprocessing_function=pretraitement_image  # Prétraitement spécifique 
)

# %%
# Créer un générateur de données pour le sous-ensemble de validation
validation_data_gen = ImageDataGenerator(
    preprocessing_function=pretraitement_image
)

# %%
# Créer un générateur de données pour le sous-ensemble de tests
test_data_gen = ImageDataGenerator(
    preprocessing_function=pretraitement_image
)

# %% [markdown]
# ## 1.3 Chargement et préparation des images test et train

# %%
# Chemin vers le dossier contenant les images du dataset
data_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/Images"

# %%
# Définir le rapport de division entre l'entraînement et la validation
# Ici, on utilise 80% pour l'entraînement et 20% pour la validation
ratio = (0.8, 0.2)

output_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/output"
remove_all_files_and_directories(output_dir)

# Diviser les images en sous-ensembles d'entraînement et de validation
splitfolders.ratio(data_dir, output=output_dir, seed=123, ratio=ratio, group_prefix=None)

# Chemin vers le dossier contenant les images d'entraînement
train_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/output/train"

# Chemin vers le dossier contenant les images de validation
validation_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/output/val"
# Out:
# Copying files: 20580 files [00:54, 375.45 files/s]

# %%
# Chargement des images avec leurs classes
batch_size = 32
img_height, img_width = 224, 224  # Vous pouvez ajuster la taille des images selon vos besoins

# Charger les images pour l'entraînement
train_images = train_data_augmentation.flow_from_directory(
    train_dir,
    color_mode="rgb",
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=42
)

# Charger les images pour la validation
validation_images = validation_data_gen.flow_from_directory(
    validation_dir,
    color_mode="rgb",
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=42
)
# Out:
# Found 16418 images belonging to 120 classes.
# Found 4162 images belonging to 120 classes.

# %%
# Obtenir les classes de chiens à partir de l'objet train_images
class_indices = train_images.class_indices

# Inverser le dictionnaire pour obtenir les noms de classes associés aux identifiants de classe
class_names = list(class_indices.keys())

print("Classes de chiens :", class_names[:10])
# Out:
# Classes de chiens : ['n02085620-Chihuahua', 'n02085782-Japanese_spaniel', 'n02085936-Maltese_dog', 'n02086079-Pekinese', 'n02086240-Shih-Tzu', 'n02086646-Blenheim_spaniel', 'n02086910-papillon', 'n02087046-toy_terrier', 'n02087394-Rhodesian_ridgeback', 'n02088094-Afghan_hound']

# %% [markdown]
# ## 1.4 Chargement et préparation d'un subset des images augmentés

# %% [markdown]
# # 1.4.1 Création du subset images

# %%
# Chemin vers le dossier contenant toutes les images du dataset
data_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/Images"

# Définir les classes que vous souhaitez charger
selected_classes = ['n02087046-toy_terrier', 'n02091134-whippet', 'n02098413-Lhasa']

# Définir le nombre d'images par classe que vous souhaitez charger
num_images_per_class = 100

# Chemin vers le dossier où vous souhaitez sauvegarder le sous-ensemble d'images
subset_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/sous_ensemble/Images"

# Call the function to remove all files and directories
remove_all_files_and_directories(subset_dir)

# Parcourir les sous-dossiers correspondant aux classes sélectionnées
for class_name in selected_classes:
    class_dir = os.path.join(data_dir, class_name)
    subset_class_dir = os.path.join(subset_dir, class_name)

    # Créer le dossier de sortie pour la classe si celui-ci n'existe pas déjà
    os.makedirs(subset_class_dir, exist_ok=True)

    # Charger la liste des fichiers d'images dans le sous-dossier de la classe
    image_files = os.listdir(class_dir)

    # Sélectionner un nombre aléatoire d'images pour la classe
    selected_images = random.sample(image_files, num_images_per_class)

    # Copier les images sélectionnées dans le dossier de sortie pour la classe
    for image_file in selected_images:
        src_path = os.path.join(class_dir, image_file)
        dst_path = os.path.join(subset_class_dir, image_file)
        copyfile(src_path, dst_path)

# %% [markdown]
# # 1.4.2 Chargement et préparation par data generator

# %%
import splitfolders
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Définir la taille des images pour le modèle
img_height, img_width = 224, 224
batch_size = 32

# Chemin vers le dossier de sortie pour le sous-ensemble
subset_output_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/sous_ensemble/output"

# Call the function to remove all files and directories
remove_all_files_and_directories(subset_output_dir)

# Utiliser splitfolders pour diviser les images en ensembles d'entraînement et de validation
splitfolders.ratio(subset_dir, output=subset_output_dir, seed=123, ratio=(0.8, 0.2), group_prefix=None)        

# Chemin vers le dossier contenant les images d'entraînement
subset_train_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/sous_ensemble/output/train"

# Chemin vers le dossier contenant les images de validation
subset_validation_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/sous_ensemble/output/val"

# Créer un générateur de données pour le sous-ensemble d'entraînement
train_data_gen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    preprocessing_function=pretraitement_image
)

subset_train_images = train_data_gen.flow_from_directory(
    subset_train_dir,
    color_mode="rgb",
    class_mode='categorical',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=True,
    seed=42
)

# Créer un générateur de données pour le sous-ensemble de validation
validation_data_gen = ImageDataGenerator(
    preprocessing_function=pretraitement_image
)

subset_validation_images = validation_data_gen.flow_from_directory(
    subset_validation_dir,
    color_mode="rgb",
    class_mode='categorical',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=True,
    seed=42
)
# Out:
# Copying files: 300 files [00:00, 436.03 files/s]
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %%
# Obtenir les classes de chiens à partir de l'objet train_images
class_indices = subset_train_images.class_indices

# Inverser le dictionnaire pour obtenir les noms de classes associés aux identifiants de classe
class_names = list(class_indices.keys())

print("Classes de chiens :", class_names)
# Out:
# Classes de chiens : ['n02087046-toy_terrier', 'n02091134-whippet', 'n02098413-Lhasa']

# %%
# Get the next batch from the data generator
batch = next(subset_train_images)

# Check the content and structure of the batch
print("Batch size:", len(batch))  # Size of the batch
#print("Batch data:", batch)       # Contents of the batch (e.g., images and labels)
# Out:
# Batch size: 2

# %% [raw]
# préparation des images de test pour prédiction

# %%
# Chemin vers le dossier contenant les images de validation
subset_validation_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/sous_ensemble/output/val"

# Replace these paths with your actual directory paths
subset_test_dir = 'C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/sous_ensemble/output/test'

remove_all_files_and_directories(subset_test_dir)

# Create the test directory if it doesn't exist
if not os.path.exists(subset_test_dir):
    os.makedirs(subset_test_dir)
    subset_test_dir_img = os.path.join(subset_test_dir, 'img')
    os.makedirs(subset_test_dir_img)

# Traverse the subdirectories in the validation directory
for root, _, files in os.walk(subset_validation_dir):
    for image_file in files:
        src = os.path.join(root, image_file)
        dst = os.path.join(subset_test_dir_img, image_file)
        shutil.copyfile(src, dst)

print("Images copied from validation to test directory.")
# Out:
# The directory 'C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/sous_ensemble/output/test' does not exist.
# Images copied from validation to test directory.

# %%
# Créer un générateur de données pour le sous-ensemble de test

subset_test_images = test_data_gen.flow_from_directory(
    subset_test_dir,
    color_mode="rgb",
    class_mode=None,
    target_size=(img_height, img_width),
    batch_size=1,
    shuffle=False,
    seed=42
)
# Out:
# Found 60 images belonging to 1 classes.

# %%
# Get the next batch from the data generator
batch = next(subset_test_images)

# Check the content and structure of the batch
print("Batch size:", len(batch))  # Size of the batch
#print("Batch data:", batch)       # Contents of the batch (e.g., images and labels)
# Out:
# Batch size: 1

# %% [markdown]
# # 2. CNN construction

# %% [markdown]
# ## 2.1 Construction Modèle

# %%
# Définir l'architecture du modèle CNN
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),    
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(3, activation='softmax')
])

# Compiler le modèle
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Afficher un résumé du modèle
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 64)                5537856
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 5,640,547
# Trainable params: 5,640,547
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2.2. Entrainement

# %% [markdown]
# Entrainement du modèle avec les sous ensembles images
# model.fit_generator est choisit pour utiliser les images préparées avec pretraitement et data augmentation.

# %%
hist=model.fit_generator(generator = subset_train_images,
                         epochs=20,
                         validation_data=subset_validation_images)
model_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/models"

model_path = os.path.join(model_dir, "model6.h5")
model.save(model_path)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 32s 4s/step - loss: 2.8610 - accuracy: 0.3417 - val_loss: 1.0874 - val_accuracy: 0.3333
# Epoch 2/20
# 8/8 [==============================] - 32s 4s/step - loss: 1.0851 - accuracy: 0.3375 - val_loss: 1.0876 - val_accuracy: 0.3333
# Epoch 3/20
# 8/8 [==============================] - 30s 4s/step - loss: 1.0872 - accuracy: 0.3250 - val_loss: 1.0656 - val_accuracy: 0.3333
# Epoch 4/20
# 8/8 [==============================] - 32s 4s/step - loss: 1.0645 - accuracy: 0.3917 - val_loss: 1.0269 - val_accuracy: 0.5667
# Epoch 5/20
# 8/8 [==============================] - 30s 4s/step - loss: 1.0570 - accuracy: 0.4917 - val_loss: 1.0105 - val_accuracy: 0.4667
# Epoch 6/20
# 8/8 [==============================] - 29s 4s/step - loss: 1.0260 - accuracy: 0.4792 - val_loss: 0.9966 - val_accuracy: 0.5667
# Epoch 7/20
# 8/8 [==============================] - 29s 4s/step - loss: 0.9846 - accuracy: 0.5042 - val_loss: 0.9005 - val_accuracy: 0.6333
# Epoch 8/20
# 8/8 [==============================] - 31s 4s/step - loss: 0.9521 - accuracy: 0.5458 - val_loss: 1.0121 - val_accuracy: 0.5500
# Epoch 9/20
# 8/8 [==============================] - 29s 4s/step - loss: 1.0320 - accuracy: 0.4833 - val_loss: 0.9920 - val_accuracy: 0.5167
# Epoch 10/20
# 8/8 [==============================] - 31s 4s/step - loss: 0.9486 - accuracy: 0.5583 - val_loss: 0.9255 - val_accuracy: 0.5167
# Epoch 11/20
# 8/8 [==============================] - 29s 4s/step - loss: 0.9293 - accuracy: 0.5542 - val_loss: 0.8836 - val_accuracy: 0.5667
# Epoch 12/20
# 8/8 [==============================] - 29s 4s/step - loss: 0.9068 - accuracy: 0.5542 - val_loss: 0.8810 - val_accuracy: 0.5833
# Epoch 13/20
# 8/8 [==============================] - 29s 3s/step - loss: 0.8693 - accuracy: 0.5750 - val_loss: 0.8555 - val_accuracy: 0.6000
# Epoch 14/20
# 8/8 [==============================] - 29s 3s/step - loss: 0.8961 - accuracy: 0.5333 - val_loss: 0.8313 - val_accuracy: 0.6167
# Epoch 15/20
# 8/8 [==============================] - 30s 4s/step - loss: 0.8760 - accuracy: 0.5667 - val_loss: 0.8367 - val_accuracy: 0.6167
# Epoch 16/20
# 8/8 [==============================] - 29s 4s/step - loss: 0.8481 - accuracy: 0.5958 - val_loss: 0.8972 - val_accuracy: 0.5500
# Epoch 17/20
# 8/8 [==============================] - 29s 4s/step - loss: 0.8833 - accuracy: 0.5667 - val_loss: 0.8312 - val_accuracy: 0.6167
# Epoch 18/20
# 8/8 [==============================] - 30s 4s/step - loss: 0.9076 - accuracy: 0.5583 - val_loss: 0.8248 - val_accuracy: 0.6667
# Epoch 19/20
# 8/8 [==============================] - 31s 4s/step - loss: 0.8984 - accuracy: 0.5583 - val_loss: 0.9468 - val_accuracy: 0.5333
# Epoch 20/20
# 8/8 [==============================] - 30s 4s/step - loss: 0.9410 - accuracy: 0.5250 - val_loss: 0.9171 - val_accuracy: 0.5167

# %%
def plot_model_history(model_history, start_epoch, acc='accuracy', val_acc='val_accuracy'):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs = range(start_epoch, start_epoch + len(model_history.history[acc]))
    
    axs[0].plot(epochs, model_history.history[acc])
    axs[0].plot(epochs, model_history.history[val_acc])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'val'], loc='best')
    
    axs[1].plot(epochs, model_history.history['loss'])
    axs[1].plot(epochs, model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'val'], loc='best')
    
    plt.show()

# %%
plot_model_history(hist, start_epoch=1)

# %% [markdown]
# ## 2.3 Evaluation de performance

# %%
# Evaluation de performance 
loss, accuracy = model.evaluate_generator(subset_validation_images)
print("Test: accuracy = %f  ;  loss = %f " % (accuracy, loss))
# Out:
# Test: accuracy = 0.516667  ;  loss = 0.917058

# %%
# prediction des classes dans le subset de validation
y_pred_val =  model.predict(subset_validation_images)
predicted_class_indices_val=np.argmax(y_pred_val,axis=1)

labels = (subset_train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())

# %%
# Culcule la matrice de confusion pour les 3 classses
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Calculate the confusion matrix
y_true = subset_validation_images.classes
conf_matrix = confusion_matrix(y_true, predicted_class_indices_val)

# Create a list of class names (assuming the order of classes in the dictionary)
class_names = list(labels.values())

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## 2.4 Prédiction

# %% [raw]
# prédiction des classes sur le subset d'image de test sans labels.

# %%
STEP_SIZE_TEST=subset_test_images.n//subset_test_images.batch_size
subset_test_images.reset()

# prediction des classes dans le subset de tests
y_pred =  model.predict(subset_test_images)

predicted_class_indices=np.argmax(y_pred,axis=1)

labels = (subset_train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
# Out:
# 60/60 [==============================] - 4s 65ms/step

# %%
filenames=subset_test_images.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})
results.to_csv("results.csv",index=False)

# %%
# Calculer l'entropie croisée pour chaque prédiction
cross_entropy = -np.sum(y_pred * np.log(y_pred), axis=1)

# La confiance est l'inverse de l'entropie croisée (plus la valeur est grande, moins le modèle est sûr)
confidence = 1.0 - cross_entropy

# Vous pouvez maintenant utiliser la valeur de 'confidence' pour évaluer la confiance des prédictions
# pour chaque image de test.
# Appliquer la fonction softmax pour obtenir les probabilités normalisées
probabilities = np.exp(confidence) / np.sum(np.exp(confidence))

print(probabilities)
# Out:
# [0.01449797 0.01417444 0.015144   0.01599371 0.0166902  0.01482982
#  0.01422697 0.01420321 0.01561017 0.01697989 0.0149777  0.0237427
#  0.01472868 0.0151741  0.01739916 0.01635783 0.01619596 0.01450865
#  0.014979   0.01729156 0.01895054 0.0144836  0.02706883 0.01602474
#  0.01438047 0.01663277 0.01561355 0.01488236 0.01451558 0.01424792
#  0.01500532 0.01489788 0.01458899 0.01434395 0.01542886 0.01414661
#  0.01432    0.01957271 0.01864416 0.02095061 0.01578358 0.01492905
#  0.01974061 0.01601972 0.01557041 0.0170338  0.01952251 0.01747277
#  0.01798123 0.0176081  0.01475002 0.0157225  0.02105844 0.02087217
#  0.02021331 0.01436335 0.01966155 0.01546072 0.01942972 0.02040125]

# %%
# Scores de confiance (remplacez ces valeurs par les vôtres)
confidence_scores = np.array([-0.07237637, -0.09494436, 0.02581084, 0.06843698, 0.55199784, 0.02774906, 0.00175416, -0.04620838])

# Appliquer la fonction softmax pour obtenir les probabilités normalisées
probabilities = np.exp(confidence_scores) / np.sum(np.exp(confidence_scores))

print(probabilities)
# Out:
# [0.10743549 0.10503804 0.11851953 0.12368078 0.20059035 0.11874947
#  0.11570237 0.11028397]

# %% [markdown]
# ## 2.5   Un autre modèle CNN Spécifique

# %% [markdown]
# ## 3. Hyperparamètres

# %% [raw]
# Nous allons chercher les hyperparamètres suivants :
# 1) le nombre de filtres pour couche de convolution
# 2) le nombre epoch d'entrainement
# 3) l'optimizer de la compilation
# 4) le nombre unit dans les couches dense

# %% [markdown]
# ## 3.1  Définir le modèle de base avec hyperparamètres

# %%
# Définir le modèle CNN peu profond e 6 couches, sur l'architecture VGG
def hyper_model6(filter_factor, num_epoch, num_units, optimizer):

    model = models.Sequential([
        layers.Conv2D(32*filter_factor, (3, 3), activation='relu', input_shape=(224, 224, 3)),
        layers.Conv2D(32*filter_factor, (3, 3), activation='relu'),    
        layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
        layers.Conv2D(64*filter_factor, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
        layers.Conv2D(128*filter_factor, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
        layers.Flatten(),
        layers.Dense(num_units, activation='relu'),
        layers.Dense(3, activation='softmax')
    ])
    
    # Compiler le modèle
    model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    start_time = time.time()
    
    # entrainer le modèle
    hist=model.fit_generator(generator = subset_train_images,
                         epochs=num_epoch,
                         validation_data=subset_validation_images)
    
    end_time = time.time()
    execution_time = end_time - start_time
    
    model_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/models"
    
    model_name = f"model6_F{filter_factor}_U{num_units}_E{num_epoch}_O{optimizer}.h5"
    model_path = os.path.join(model_dir, model_name)
    model.save(model_path)    
    
    # evaluer le modèle
    loss, accuracy = model.evaluate_generator(subset_validation_images)
    
    resultat = ['model6',filter_factor,num_units, num_epoch, optimizer, round(loss, 4), round(accuracy, 4), round(execution_time, 0)]
    return resultat

# %% [markdown]
# ## 3.2.  Entrainement des modèles avec combinaisons des valeurs de hyperparamètres

# %% [raw]
# Les valeurs de hyperparamètres testés
# 1) filter_factor: (1, 3)
# 2) num_units: (64, 256)
# 3) num_epoch : (10, 30)
# 4) optimizer: ('adam', 'rmsprop', 'sgd')

# %%
performance_list = []

# %%
import itertools

# Define the ranges for each hyperparameter
filter_factors = [1, 3]
num_units = [64, 256]
num_epochs = [10, 30]
optimizers = ['adam', 'rmsprop', 'sgd']

# %%
# Loop through all combinations of hyperparameters
for filter_factor in filter_factors:
    for num_unit in num_units:
        for num_epoch in num_epochs:
            for optimizer in optimizers:
                # Create a tuple representing the current combination
                resultat = hyper_model6(filter_factor=filter_factor, \
                        num_epoch=num_epoch, num_units=num_unit, optimizer=optimizer)
                performance_list.append(resultat)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 31s 4s/step - loss: 94.5407 - accuracy: 0.2958 - val_loss: 2.0528 - val_accuracy: 0.2500
# Epoch 2/10
# 8/8 [==============================] - 28s 3s/step - loss: 1.6985 - accuracy: 0.3375 - val_loss: 1.0751 - val_accuracy: 0.4167
# Epoch 3/10
# 8/8 [==============================] - 28s 3s/step - loss: 1.0709 - accuracy: 0.4583 - val_loss: 1.0727 - val_accuracy: 0.4167
# Epoch 4/10
# 8/8 [==============================] - 28s 3s/step - loss: 1.0784 - accuracy: 0.4125 - val_loss: 1.0781 - val_accuracy: 0.4667
# Epoch 5/10
# 8/8 [==============================] - 29s 4s/step - loss: 1.0473 - accuracy: 0.4458 - val_loss: 1.0745 - val_accuracy: 0.5000
# Epoch 6/10
# 8/8 [==============================] - 28s 3s/step - loss: 1.0372 - accuracy: 0.4875 - val_loss: 1.1035 - val_accuracy: 0.4333
# Epoch 7/10
# 8/8 [==============================] - 29s 3s/step - loss: 1.0637 - accuracy: 0.4167 - val_loss: 1.0789 - val_accuracy: 0.4667
# Epoch 8/10
# 8/8 [==============================] - 30s 4s/step - loss: 1.0343 - accuracy: 0.4833 - val_loss: 1.1636 - val_accuracy: 0.3833
# Epoch 9/10
# 8/8 [==============================] - 30s 4s/step - loss: 1.0177 - accuracy: 0.4625 - val_loss: 1.0815 - val_accuracy: 0.4500
# Epoch 10/10
# 8/8 [==============================] - 31s 4s/step - loss: 1.0307 - accuracy: 0.4708 - val_loss: 1.1564 - val_accuracy: 0.3667
# Epoch 1/10
# 8/8 [==============================] - 31s 4s/step - loss: 480.4220 - accuracy: 0.3333 - val_loss: 8.4067 - val_accuracy: 0.3333
# Epoch 2/10
# 8/8 [==============================] - 29s 4s/step - loss: 2.4328 - accuracy: 0.3000 - val_loss: 1.1201 - val_accuracy: 0.3167
# Epoch 3/10
# 8/8 [==============================] - 30s 4s/step - loss: 1.0977 - accuracy: 0.3500 - val_loss: 1.0944 - val_accuracy: 0.3833
# Epoch 4/10
# 8/8 [==============================] - 29s 4s/step - loss: 1.1164 - accuracy: 0.3083 - val_loss: 1.0793 - val_accuracy: 0.3333
# Epoch 5/10
# 8/8 [==============================] - 32s 4s/step - loss: 1.1793 - accuracy: 0.4375 - val_loss: 1.0751 - val_accuracy: 0.4167
# Epoch 6/10
# 8/8 [==============================] - 31s 4s/step - loss: 1.0521 - accuracy: 0.4292 - val_loss: 1.1730 - val_accuracy: 0.4000
# Epoch 7/10
# 8/8 [==============================] - 28s 4s/step - loss: 1.3586 - accuracy: 0.4375 - val_loss: 1.0652 - val_accuracy: 0.4167
# Epoch 8/10
# 8/8 [==============================] - 28s 3s/step - loss: 1.0586 - accuracy: 0.4167 - val_loss: 1.0374 - val_accuracy: 0.4167
# Epoch 9/10
# 8/8 [==============================] - 29s 4s/step - loss: 4.9122 - accuracy: 0.3500 - val_loss: 1.1878 - val_accuracy: 0.3333
# Epoch 10/10
# 8/8 [==============================] - 28s 3s/step - loss: 1.0410 - accuracy: 0.4125 - val_loss: 1.0326 - val_accuracy: 0.4333
# Epoch 1/10
# 8/8 [==============================] - 32s 4s/step - loss: nan - accuracy: 0.3083 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/10
# 8/8 [==============================] - 29s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/10
# 8/8 [==============================] - 29s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/10
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/10
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 6/10
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 7/10
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 8/10
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 9/10
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 10/10
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 1/30
# 8/8 [==============================] - 30s 4s/step - loss: 240.2469 - accuracy: 0.3917 - val_loss: 4.7555 - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.6343 - accuracy: 0.4042 - val_loss: 1.0998 - val_accuracy: 0.3333
# Epoch 3/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0745 - accuracy: 0.3583 - val_loss: 1.0844 - val_accuracy: 0.3500
# Epoch 4/30
# 8/8 [==============================] - 30s 4s/step - loss: 1.0707 - accuracy: 0.4000 - val_loss: 1.0787 - val_accuracy: 0.3167
# Epoch 5/30
# 8/8 [==============================] - 29s 3s/step - loss: 1.0615 - accuracy: 0.4083 - val_loss: 1.0995 - val_accuracy: 0.3833
# Epoch 6/30
# 8/8 [==============================] - 28s 3s/step - loss: 1.0126 - accuracy: 0.5000 - val_loss: 1.0591 - val_accuracy: 0.4167
# Epoch 7/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.0542 - accuracy: 0.4708 - val_loss: 1.0620 - val_accuracy: 0.4000
# Epoch 8/30
# 8/8 [==============================] - 28s 3s/step - loss: 1.0372 - accuracy: 0.4500 - val_loss: 1.0720 - val_accuracy: 0.3833
# Epoch 9/30
# 8/8 [==============================] - 30s 4s/step - loss: 1.0395 - accuracy: 0.4417 - val_loss: 1.0819 - val_accuracy: 0.3167
# Epoch 10/30
# 8/8 [==============================] - 29s 3s/step - loss: 1.0196 - accuracy: 0.4875 - val_loss: 1.1290 - val_accuracy: 0.4333
# Epoch 11/30
# 8/8 [==============================] - 34s 4s/step - loss: 1.0421 - accuracy: 0.4208 - val_loss: 1.0843 - val_accuracy: 0.4167
# Epoch 12/30
# 8/8 [==============================] - 34s 4s/step - loss: 1.0136 - accuracy: 0.5042 - val_loss: 1.0900 - val_accuracy: 0.4167
# Epoch 13/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.0110 - accuracy: 0.4833 - val_loss: 1.1519 - val_accuracy: 0.4000
# Epoch 14/30
# 8/8 [==============================] - 29s 4s/step - loss: 0.9895 - accuracy: 0.5125 - val_loss: 1.1160 - val_accuracy: 0.3833
# Epoch 15/30
# 8/8 [==============================] - 29s 4s/step - loss: 0.9818 - accuracy: 0.5292 - val_loss: 1.1491 - val_accuracy: 0.4000
# Epoch 16/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0615 - accuracy: 0.4750 - val_loss: 1.0819 - val_accuracy: 0.3667
# Epoch 17/30
# 8/8 [==============================] - 31s 4s/step - loss: 1.0229 - accuracy: 0.5000 - val_loss: 1.0975 - val_accuracy: 0.4000
# Epoch 18/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0338 - accuracy: 0.5042 - val_loss: 1.1229 - val_accuracy: 0.3500
# Epoch 19/30
# 8/8 [==============================] - 28s 4s/step - loss: 0.9671 - accuracy: 0.5375 - val_loss: 1.1988 - val_accuracy: 0.3500
# Epoch 20/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0554 - accuracy: 0.4958 - val_loss: 1.1003 - val_accuracy: 0.4167
# Epoch 21/30
# 8/8 [==============================] - 29s 3s/step - loss: 1.0080 - accuracy: 0.4917 - val_loss: 1.0718 - val_accuracy: 0.4167
# Epoch 22/30
# 8/8 [==============================] - 28s 3s/step - loss: 0.9756 - accuracy: 0.5833 - val_loss: 1.0679 - val_accuracy: 0.5000
# Epoch 23/30
# 8/8 [==============================] - 27s 3s/step - loss: 0.9653 - accuracy: 0.5833 - val_loss: 1.0898 - val_accuracy: 0.5000
# Epoch 24/30
# 8/8 [==============================] - 28s 3s/step - loss: 0.9539 - accuracy: 0.5250 - val_loss: 1.0549 - val_accuracy: 0.4667
# Epoch 25/30
# 8/8 [==============================] - 29s 4s/step - loss: 0.9609 - accuracy: 0.5708 - val_loss: 1.0655 - val_accuracy: 0.4333
# Epoch 26/30
# 8/8 [==============================] - 29s 4s/step - loss: 0.9572 - accuracy: 0.5750 - val_loss: 1.1148 - val_accuracy: 0.5167
# Epoch 27/30
# 8/8 [==============================] - 27s 3s/step - loss: 0.9428 - accuracy: 0.5500 - val_loss: 1.1039 - val_accuracy: 0.5167
# Epoch 28/30
# 8/8 [==============================] - 27s 3s/step - loss: 0.9098 - accuracy: 0.5375 - val_loss: 1.1260 - val_accuracy: 0.4667
# Epoch 29/30
# 8/8 [==============================] - 28s 4s/step - loss: 0.9922 - accuracy: 0.5458 - val_loss: 1.0461 - val_accuracy: 0.4500
# Epoch 30/30
# 8/8 [==============================] - 29s 4s/step - loss: 0.9670 - accuracy: 0.5250 - val_loss: 1.0266 - val_accuracy: 0.4500
# Epoch 1/30
# 8/8 [==============================] - 31s 4s/step - loss: 102.8791 - accuracy: 0.3875 - val_loss: 1.3245 - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.1580 - accuracy: 0.4042 - val_loss: 2.1533 - val_accuracy: 0.3333
# Epoch 3/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.2889 - accuracy: 0.4500 - val_loss: 1.1524 - val_accuracy: 0.3333
# Epoch 4/30
# 8/8 [==============================] - 29s 3s/step - loss: 1.2047 - accuracy: 0.3917 - val_loss: 1.2798 - val_accuracy: 0.3333
# Epoch 5/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.0683 - accuracy: 0.4417 - val_loss: 1.2045 - val_accuracy: 0.3333
# Epoch 6/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0488 - accuracy: 0.4625 - val_loss: 1.4401 - val_accuracy: 0.3833
# Epoch 7/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.2157 - accuracy: 0.4625 - val_loss: 1.0705 - val_accuracy: 0.3833
# Epoch 8/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.4332 - accuracy: 0.4125 - val_loss: 1.0590 - val_accuracy: 0.4333
# Epoch 9/30
# 8/8 [==============================] - 26s 3s/step - loss: 1.0125 - accuracy: 0.4667 - val_loss: 1.0781 - val_accuracy: 0.3833
# Epoch 10/30
# 8/8 [==============================] - 27s 3s/step - loss: 0.9830 - accuracy: 0.5208 - val_loss: 2.3167 - val_accuracy: 0.3333
# Epoch 11/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.2321 - accuracy: 0.4000 - val_loss: 1.0175 - val_accuracy: 0.4667
# Epoch 12/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.0858 - accuracy: 0.4708 - val_loss: 1.0286 - val_accuracy: 0.4833
# Epoch 13/30
# 8/8 [==============================] - 29s 3s/step - loss: 1.0148 - accuracy: 0.4792 - val_loss: 1.0350 - val_accuracy: 0.4667
# Epoch 14/30
# 8/8 [==============================] - 26s 3s/step - loss: 5.0607 - accuracy: 0.4250 - val_loss: 1.0795 - val_accuracy: 0.4000
# Epoch 15/30
# 8/8 [==============================] - 28s 4s/step - loss: 1.0180 - accuracy: 0.4708 - val_loss: 1.1443 - val_accuracy: 0.4167
# Epoch 16/30
# 8/8 [==============================] - 28s 3s/step - loss: 1.0349 - accuracy: 0.4917 - val_loss: 1.0452 - val_accuracy: 0.4667
# Epoch 17/30
# 8/8 [==============================] - 28s 3s/step - loss: 1.0233 - accuracy: 0.4625 - val_loss: 1.0560 - val_accuracy: 0.4167
# Epoch 18/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.0822 - accuracy: 0.5333 - val_loss: 1.0398 - val_accuracy: 0.4333
# Epoch 19/30
# 8/8 [==============================] - 28s 3s/step - loss: 0.9861 - accuracy: 0.4917 - val_loss: 1.0435 - val_accuracy: 0.4333
# Epoch 20/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.0790 - accuracy: 0.4417 - val_loss: 1.4308 - val_accuracy: 0.4167
# Epoch 21/30
# 8/8 [==============================] - 28s 3s/step - loss: 1.0047 - accuracy: 0.5292 - val_loss: 1.0965 - val_accuracy: 0.5000
# Epoch 22/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.3246 - accuracy: 0.4542 - val_loss: 15.2013 - val_accuracy: 0.3333
# Epoch 23/30
# 8/8 [==============================] - 27s 3s/step - loss: 2.3293 - accuracy: 0.4917 - val_loss: 1.1007 - val_accuracy: 0.4833
# Epoch 24/30
# 8/8 [==============================] - 27s 3s/step - loss: 0.9881 - accuracy: 0.4958 - val_loss: 1.0442 - val_accuracy: 0.4833
# Epoch 25/30
# 8/8 [==============================] - 28s 3s/step - loss: 0.9474 - accuracy: 0.5083 - val_loss: 1.0972 - val_accuracy: 0.5667
# Epoch 26/30
# 8/8 [==============================] - 28s 3s/step - loss: 0.9670 - accuracy: 0.5583 - val_loss: 1.0597 - val_accuracy: 0.5333
# Epoch 27/30
# 8/8 [==============================] - 27s 3s/step - loss: 0.9638 - accuracy: 0.5625 - val_loss: 1.0442 - val_accuracy: 0.5167
# Epoch 28/30
# 8/8 [==============================] - 29s 4s/step - loss: 0.9934 - accuracy: 0.5208 - val_loss: 1.0355 - val_accuracy: 0.5000
# Epoch 29/30
# 8/8 [==============================] - 27s 3s/step - loss: 0.9689 - accuracy: 0.5167 - val_loss: 0.9580 - val_accuracy: 0.5500
# Epoch 30/30
# 8/8 [==============================] - 27s 3s/step - loss: 0.9257 - accuracy: 0.5750 - val_loss: 1.0662 - val_accuracy: 0.4833
# Epoch 1/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3083 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/30
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 6/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 7/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 8/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 9/30
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 10/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 11/30
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 12/30
# 8/8 [==============================] - 27s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 13/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 14/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 15/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 16/30
# 8/8 [==============================] - 29s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 17/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 18/30
# 8/8 [==============================] - 29s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 19/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 20/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 21/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 22/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 23/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 24/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 25/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 26/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 27/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 28/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 29/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 30/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 1/10
# 8/8 [==============================] - 34s 4s/step - loss: 327.0647 - accuracy: 0.3625 - val_loss: 3.8330 - val_accuracy: 0.3333
# Epoch 2/10
# 8/8 [==============================] - 29s 4s/step - loss: 1.9509 - accuracy: 0.3417 - val_loss: 1.0723 - val_accuracy: 0.3667
# Epoch 3/10
# 8/8 [==============================] - 30s 4s/step - loss: 1.0407 - accuracy: 0.4208 - val_loss: 1.0762 - val_accuracy: 0.3500
# Epoch 4/10
# 8/8 [==============================] - 28s 3s/step - loss: 1.0325 - accuracy: 0.4458 - val_loss: 1.0583 - val_accuracy: 0.4000
# Epoch 5/10
# 8/8 [==============================] - 29s 3s/step - loss: 1.0207 - accuracy: 0.4625 - val_loss: 1.0741 - val_accuracy: 0.4333
# Epoch 6/10
# 8/8 [==============================] - 31s 4s/step - loss: 1.0499 - accuracy: 0.4500 - val_loss: 1.0682 - val_accuracy: 0.4333
# Epoch 7/10
# 8/8 [==============================] - 29s 4s/step - loss: 1.0337 - accuracy: 0.4708 - val_loss: 1.0882 - val_accuracy: 0.4000
# Epoch 8/10
# 8/8 [==============================] - 29s 3s/step - loss: 1.0135 - accuracy: 0.4917 - val_loss: 1.0494 - val_accuracy: 0.4833
# Epoch 9/10
# 8/8 [==============================] - 29s 4s/step - loss: 0.9961 - accuracy: 0.5292 - val_loss: 0.9937 - val_accuracy: 0.5167
# Epoch 10/10
# 8/8 [==============================] - 30s 4s/step - loss: 1.0192 - accuracy: 0.4542 - val_loss: 1.0530 - val_accuracy: 0.4333
# Epoch 1/10
# 8/8 [==============================] - 33s 4s/step - loss: 779.9910 - accuracy: 0.3500 - val_loss: 1.1379 - val_accuracy: 0.2500
# Epoch 2/10
# 8/8 [==============================] - 31s 4s/step - loss: 1.4959 - accuracy: 0.3500 - val_loss: 1.1197 - val_accuracy: 0.3000
# Epoch 3/10
# 8/8 [==============================] - 30s 4s/step - loss: 1.0662 - accuracy: 0.4375 - val_loss: 1.0906 - val_accuracy: 0.3500
# Epoch 4/10
# 8/8 [==============================] - 30s 4s/step - loss: 1.0720 - accuracy: 0.4167 - val_loss: 1.0769 - val_accuracy: 0.3667
# Epoch 5/10
# 8/8 [==============================] - 31s 4s/step - loss: 1.0396 - accuracy: 0.4375 - val_loss: 1.0902 - val_accuracy: 0.3667
# Epoch 6/10
# 8/8 [==============================] - 31s 4s/step - loss: 1.0867 - accuracy: 0.4500 - val_loss: 1.0889 - val_accuracy: 0.4500
# Epoch 7/10
# 8/8 [==============================] - 33s 4s/step - loss: 1.0507 - accuracy: 0.5125 - val_loss: 1.1153 - val_accuracy: 0.3833
# Epoch 8/10
# 8/8 [==============================] - 28s 3s/step - loss: 1.0982 - accuracy: 0.4833 - val_loss: 1.1560 - val_accuracy: 0.3833
# Epoch 9/10
# 8/8 [==============================] - 29s 4s/step - loss: 1.9699 - accuracy: 0.4917 - val_loss: 1.0772 - val_accuracy: 0.4000
# Epoch 10/10
# 8/8 [==============================] - 30s 4s/step - loss: 12.3156 - accuracy: 0.3708 - val_loss: 20.8895 - val_accuracy: 0.3333
# Epoch 1/10
# 8/8 [==============================] - 37s 4s/step - loss: nan - accuracy: 0.3250 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/10
# 8/8 [==============================] - 32s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/10
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/10
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/10
# 8/8 [==============================] - 49s 7s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 6/10
# 8/8 [==============================] - 36s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 7/10
# 8/8 [==============================] - 33s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 8/10
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 9/10
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 10/10
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 1/30
# 8/8 [==============================] - 35s 4s/step - loss: 1038.1129 - accuracy: 0.3542 - val_loss: 14.1394 - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 30s 4s/step - loss: 5.9754 - accuracy: 0.3875 - val_loss: 1.7155 - val_accuracy: 0.2833
# Epoch 3/30
# 8/8 [==============================] - 31s 4s/step - loss: 1.1338 - accuracy: 0.3458 - val_loss: 1.1003 - val_accuracy: 0.2500
# Epoch 4/30
# 8/8 [==============================] - 32s 4s/step - loss: 1.0873 - accuracy: 0.4208 - val_loss: 1.0987 - val_accuracy: 0.3167
# Epoch 5/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0898 - accuracy: 0.4042 - val_loss: 1.0990 - val_accuracy: 0.3000
# Epoch 6/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0751 - accuracy: 0.3875 - val_loss: 1.1002 - val_accuracy: 0.3667
# Epoch 7/30
# 8/8 [==============================] - 33s 4s/step - loss: 1.0842 - accuracy: 0.4083 - val_loss: 1.0990 - val_accuracy: 0.3333
# Epoch 8/30
# 8/8 [==============================] - 29s 3s/step - loss: 1.0783 - accuracy: 0.3333 - val_loss: 1.1175 - val_accuracy: 0.3667
# Epoch 9/30
# 8/8 [==============================] - 30s 4s/step - loss: 1.0816 - accuracy: 0.3917 - val_loss: 1.1095 - val_accuracy: 0.4000
# Epoch 10/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0805 - accuracy: 0.4042 - val_loss: 1.0981 - val_accuracy: 0.4000
# Epoch 11/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0372 - accuracy: 0.4583 - val_loss: 1.1084 - val_accuracy: 0.4000
# Epoch 12/30
# 8/8 [==============================] - 28s 3s/step - loss: 1.0684 - accuracy: 0.4500 - val_loss: 1.0852 - val_accuracy: 0.4000
# Epoch 13/30
# 8/8 [==============================] - 29s 3s/step - loss: 1.0273 - accuracy: 0.4875 - val_loss: 1.1091 - val_accuracy: 0.3500
# Epoch 14/30
# 8/8 [==============================] - 30s 4s/step - loss: 1.0247 - accuracy: 0.5000 - val_loss: 1.1642 - val_accuracy: 0.4500
# Epoch 15/30
# 8/8 [==============================] - 30s 4s/step - loss: 1.0438 - accuracy: 0.4625 - val_loss: 1.0732 - val_accuracy: 0.3667
# Epoch 16/30
# 8/8 [==============================] - 28s 3s/step - loss: 1.0035 - accuracy: 0.4917 - val_loss: 1.0670 - val_accuracy: 0.4333
# Epoch 17/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.0048 - accuracy: 0.5125 - val_loss: 1.0536 - val_accuracy: 0.3833
# Epoch 18/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0154 - accuracy: 0.5000 - val_loss: 1.0678 - val_accuracy: 0.4500
# Epoch 19/30
# 8/8 [==============================] - 29s 3s/step - loss: 1.0229 - accuracy: 0.5083 - val_loss: 1.0534 - val_accuracy: 0.4500
# Epoch 20/30
# 8/8 [==============================] - 27s 3s/step - loss: 1.0183 - accuracy: 0.4917 - val_loss: 1.1013 - val_accuracy: 0.4000
# Epoch 21/30
# 8/8 [==============================] - 28s 3s/step - loss: 0.9977 - accuracy: 0.5250 - val_loss: 1.0765 - val_accuracy: 0.4000
# Epoch 22/30
# 8/8 [==============================] - 28s 3s/step - loss: 1.0188 - accuracy: 0.4667 - val_loss: 1.1552 - val_accuracy: 0.4000
# Epoch 23/30
# 8/8 [==============================] - 34s 4s/step - loss: 1.0146 - accuracy: 0.5125 - val_loss: 1.0723 - val_accuracy: 0.4000
# Epoch 24/30
# 8/8 [==============================] - 40s 5s/step - loss: 0.9772 - accuracy: 0.5667 - val_loss: 1.1019 - val_accuracy: 0.4333
# Epoch 25/30
# 8/8 [==============================] - 34s 4s/step - loss: 0.9768 - accuracy: 0.5833 - val_loss: 1.0611 - val_accuracy: 0.4500
# Epoch 26/30
# 8/8 [==============================] - 28s 3s/step - loss: 0.9507 - accuracy: 0.5875 - val_loss: 1.0770 - val_accuracy: 0.4167
# Epoch 27/30
# 8/8 [==============================] - 32s 4s/step - loss: 1.0181 - accuracy: 0.4917 - val_loss: 1.1326 - val_accuracy: 0.4333
# Epoch 28/30
# 8/8 [==============================] - 30s 4s/step - loss: 1.0270 - accuracy: 0.4875 - val_loss: 1.0938 - val_accuracy: 0.3833
# Epoch 29/30
# 8/8 [==============================] - 31s 4s/step - loss: 1.0286 - accuracy: 0.4875 - val_loss: 1.1047 - val_accuracy: 0.4333
# Epoch 30/30
# 8/8 [==============================] - 31s 4s/step - loss: 0.9887 - accuracy: 0.4875 - val_loss: 1.1361 - val_accuracy: 0.4167
# Epoch 1/30
# 8/8 [==============================] - 43s 5s/step - loss: 562.6436 - accuracy: 0.3208 - val_loss: 5.2914 - val_accuracy: 0.3000
# Epoch 2/30
# 8/8 [==============================] - 35s 5s/step - loss: 2.9747 - accuracy: 0.3167 - val_loss: 1.0956 - val_accuracy: 0.5167
# Epoch 3/30
# 8/8 [==============================] - 35s 4s/step - loss: 1.1179 - accuracy: 0.4208 - val_loss: 1.1017 - val_accuracy: 0.4667
# Epoch 4/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0759 - accuracy: 0.4625 - val_loss: 0.9924 - val_accuracy: 0.5167
# Epoch 5/30
# 8/8 [==============================] - 31s 4s/step - loss: 1.1766 - accuracy: 0.5250 - val_loss: 1.2339 - val_accuracy: 0.3333
# Epoch 6/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.7678 - accuracy: 0.5167 - val_loss: 8.2676 - val_accuracy: 0.3333
# Epoch 7/30
# 8/8 [==============================] - 31s 4s/step - loss: 2.2684 - accuracy: 0.3750 - val_loss: 1.0669 - val_accuracy: 0.4333
# Epoch 8/30
# 8/8 [==============================] - 31s 4s/step - loss: 1.2703 - accuracy: 0.4667 - val_loss: 1.0174 - val_accuracy: 0.5000
# Epoch 9/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.7702 - accuracy: 0.4208 - val_loss: 1.0542 - val_accuracy: 0.4333
# Epoch 10/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0438 - accuracy: 0.4208 - val_loss: 1.1497 - val_accuracy: 0.4167
# Epoch 11/30
# 8/8 [==============================] - 30s 4s/step - loss: 4.6025 - accuracy: 0.3667 - val_loss: 1.1413 - val_accuracy: 0.4333
# Epoch 12/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0470 - accuracy: 0.4417 - val_loss: 1.0663 - val_accuracy: 0.4667
# Epoch 13/30
# 8/8 [==============================] - 31s 4s/step - loss: 0.9960 - accuracy: 0.5000 - val_loss: 1.0970 - val_accuracy: 0.5000
# Epoch 14/30
# 8/8 [==============================] - 30s 4s/step - loss: 1.1312 - accuracy: 0.4708 - val_loss: 1.1120 - val_accuracy: 0.3500
# Epoch 15/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.5480 - accuracy: 0.4208 - val_loss: 10.9048 - val_accuracy: 0.4000
# Epoch 16/30
# 8/8 [==============================] - 30s 4s/step - loss: 2.3780 - accuracy: 0.4708 - val_loss: 1.0722 - val_accuracy: 0.4667
# Epoch 17/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0212 - accuracy: 0.4875 - val_loss: 1.5930 - val_accuracy: 0.4000
# Epoch 18/30
# 8/8 [==============================] - 31s 4s/step - loss: 2.3440 - accuracy: 0.4792 - val_loss: 1.5975 - val_accuracy: 0.3167
# Epoch 19/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.1079 - accuracy: 0.4375 - val_loss: 1.0800 - val_accuracy: 0.4333
# Epoch 20/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.5144 - accuracy: 0.3667 - val_loss: 1.1362 - val_accuracy: 0.3833
# Epoch 21/30
# 8/8 [==============================] - 30s 4s/step - loss: 1.0716 - accuracy: 0.3792 - val_loss: 1.0742 - val_accuracy: 0.4333
# Epoch 22/30
# 8/8 [==============================] - 29s 4s/step - loss: 1.0286 - accuracy: 0.4750 - val_loss: 1.0835 - val_accuracy: 0.4833
# Epoch 23/30
# 8/8 [==============================] - 31s 4s/step - loss: 1.0232 - accuracy: 0.4875 - val_loss: 1.2294 - val_accuracy: 0.4333
# Epoch 24/30
# 8/8 [==============================] - 31s 4s/step - loss: 1.1450 - accuracy: 0.4833 - val_loss: 1.0832 - val_accuracy: 0.4833
# Epoch 25/30
# 8/8 [==============================] - 31s 4s/step - loss: 1.0740 - accuracy: 0.4625 - val_loss: 1.3656 - val_accuracy: 0.3333
# Epoch 26/30
# 8/8 [==============================] - 34s 4s/step - loss: 1.1037 - accuracy: 0.4375 - val_loss: 1.1477 - val_accuracy: 0.3833
# Epoch 27/30
# 8/8 [==============================] - 33s 4s/step - loss: 1.0558 - accuracy: 0.4833 - val_loss: 1.1697 - val_accuracy: 0.4000
# Epoch 28/30
# 8/8 [==============================] - 34s 4s/step - loss: 1.0602 - accuracy: 0.5375 - val_loss: 1.0272 - val_accuracy: 0.4833
# Epoch 29/30
# 8/8 [==============================] - 33s 4s/step - loss: 0.9953 - accuracy: 0.5208 - val_loss: 0.9803 - val_accuracy: 0.5833
# Epoch 30/30
# 8/8 [==============================] - 32s 4s/step - loss: 0.8929 - accuracy: 0.5792 - val_loss: 1.1096 - val_accuracy: 0.5500
# Epoch 1/30
# 8/8 [==============================] - 32s 4s/step - loss: nan - accuracy: 0.3417 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/30
# 8/8 [==============================] - 32s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 6/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 7/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 8/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 9/30
# 8/8 [==============================] - 29s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 10/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 11/30
# 8/8 [==============================] - 28s 3s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 12/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 13/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 14/30
# 8/8 [==============================] - 32s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 15/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 16/30
# 8/8 [==============================] - 33s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 17/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 18/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 19/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 20/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 21/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 22/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 23/30
# 8/8 [==============================] - 31s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 24/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 25/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 26/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 27/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 28/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 29/30
# 8/8 [==============================] - 29s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 30/30
# 8/8 [==============================] - 30s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 1/10
# 8/8 [==============================] - 87s 10s/step - loss: 283.5553 - accuracy: 0.3375 - val_loss: 1.5330 - val_accuracy: 0.3833
# Epoch 2/10
# 8/8 [==============================] - 81s 10s/step - loss: 2.4914 - accuracy: 0.3708 - val_loss: 1.5391 - val_accuracy: 0.3833
# Epoch 3/10
# 8/8 [==============================] - 86s 11s/step - loss: 1.3520 - accuracy: 0.3458 - val_loss: 1.1060 - val_accuracy: 0.4667
# Epoch 4/10
# 8/8 [==============================] - 83s 10s/step - loss: 1.2397 - accuracy: 0.4125 - val_loss: 1.0985 - val_accuracy: 0.3500
# Epoch 5/10
# 8/8 [==============================] - 82s 10s/step - loss: 1.0851 - accuracy: 0.4042 - val_loss: 1.1004 - val_accuracy: 0.3833
# Epoch 6/10
# 8/8 [==============================] - 81s 10s/step - loss: 1.0766 - accuracy: 0.4875 - val_loss: 1.0901 - val_accuracy: 0.3500
# Epoch 7/10
# 8/8 [==============================] - 77s 9s/step - loss: 1.1019 - accuracy: 0.3667 - val_loss: 1.0836 - val_accuracy: 0.3667
# Epoch 8/10
# 8/8 [==============================] - 74s 9s/step - loss: 1.0662 - accuracy: 0.4083 - val_loss: 1.0797 - val_accuracy: 0.3333
# Epoch 9/10
# 8/8 [==============================] - 78s 10s/step - loss: 1.0697 - accuracy: 0.3917 - val_loss: 1.0867 - val_accuracy: 0.4000
# Epoch 10/10
# 8/8 [==============================] - 81s 10s/step - loss: 1.0711 - accuracy: 0.4167 - val_loss: 1.0853 - val_accuracy: 0.4000
# Epoch 1/10
# 8/8 [==============================] - 90s 12s/step - loss: 4952.1167 - accuracy: 0.2792 - val_loss: 1.1028 - val_accuracy: 0.3500
# Epoch 2/10
# 8/8 [==============================] - 87s 12s/step - loss: 1.0747 - accuracy: 0.4042 - val_loss: 1.0418 - val_accuracy: 0.4333
# Epoch 3/10
# 8/8 [==============================] - 80s 10s/step - loss: 1.3281 - accuracy: 0.3792 - val_loss: 1.7454 - val_accuracy: 0.3333
# Epoch 4/10
# 8/8 [==============================] - 78s 10s/step - loss: 1.2350 - accuracy: 0.3750 - val_loss: 1.9414 - val_accuracy: 0.3333
# Epoch 5/10
# 8/8 [==============================] - 84s 10s/step - loss: 1.3223 - accuracy: 0.3542 - val_loss: 1.0542 - val_accuracy: 0.4333
# Epoch 6/10
# 8/8 [==============================] - 85s 10s/step - loss: 2.0880 - accuracy: 0.4000 - val_loss: 1.0796 - val_accuracy: 0.4500
# Epoch 7/10
# 8/8 [==============================] - 87s 10s/step - loss: 1.0778 - accuracy: 0.4333 - val_loss: 1.0742 - val_accuracy: 0.4000
# Epoch 8/10
# 8/8 [==============================] - 91s 11s/step - loss: 1.3933 - accuracy: 0.3958 - val_loss: 1.0758 - val_accuracy: 0.4167
# Epoch 9/10
# 8/8 [==============================] - 94s 12s/step - loss: 5.4442 - accuracy: 0.4833 - val_loss: 56.0126 - val_accuracy: 0.3333
# Epoch 10/10
# 8/8 [==============================] - 97s 12s/step - loss: 13.3414 - accuracy: 0.3792 - val_loss: 1.0912 - val_accuracy: 0.4000
# Epoch 1/10
# 8/8 [==============================] - 86s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/10
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/10
# 8/8 [==============================] - 80s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/10
# 8/8 [==============================] - 86s 11s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/10
# 8/8 [==============================] - 84s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 6/10
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 7/10
# 8/8 [==============================] - 82s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 8/10
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 9/10
# 8/8 [==============================] - 78s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 10/10
# 8/8 [==============================] - 81s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 1/30
# 8/8 [==============================] - 88s 11s/step - loss: 575.7278 - accuracy: 0.3583 - val_loss: 1.9477 - val_accuracy: 0.4500
# Epoch 2/30
# 8/8 [==============================] - 85s 10s/step - loss: 3.7390 - accuracy: 0.3500 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 3/30
# 8/8 [==============================] - 83s 10s/step - loss: 1.4985 - accuracy: 0.3292 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 4/30
# 8/8 [==============================] - 83s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 5/30
# 8/8 [==============================] - 81s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 6/30
# 8/8 [==============================] - 90s 11s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 7/30
# 8/8 [==============================] - 101s 13s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 8/30
# 8/8 [==============================] - 97s 11s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 9/30
# 8/8 [==============================] - 86s 11s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 10/30
# 8/8 [==============================] - 86s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 11/30
# 8/8 [==============================] - 85s 11s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 12/30
# 8/8 [==============================] - 86s 11s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 13/30
# 8/8 [==============================] - 90s 11s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 14/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 15/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 16/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 17/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 18/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 19/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 20/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 21/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 22/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 23/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 24/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 25/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 26/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 27/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 28/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 29/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 30/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 1/30
# 8/8 [==============================] - 84s 10s/step - loss: 2289.8052 - accuracy: 0.3417 - val_loss: 25.5709 - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 79s 10s/step - loss: 6.2841 - accuracy: 0.3083 - val_loss: 1.0826 - val_accuracy: 0.3833
# Epoch 3/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0804 - accuracy: 0.3458 - val_loss: 1.0859 - val_accuracy: 0.3333
# Epoch 4/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0923 - accuracy: 0.3583 - val_loss: 1.0955 - val_accuracy: 0.3500
# Epoch 5/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0790 - accuracy: 0.4000 - val_loss: 1.1776 - val_accuracy: 0.3333
# Epoch 6/30
# 8/8 [==============================] - 82s 10s/step - loss: 1.2871 - accuracy: 0.3125 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 7/30
# 8/8 [==============================] - 89s 11s/step - loss: 1.0987 - accuracy: 0.2958 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 8/30
# 8/8 [==============================] - 97s 12s/step - loss: 1.0987 - accuracy: 0.3167 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 9/30
# 8/8 [==============================] - 88s 11s/step - loss: 1.0987 - accuracy: 0.3125 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 10/30
# 8/8 [==============================] - 83s 10s/step - loss: 1.0987 - accuracy: 0.3250 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 11/30
# 8/8 [==============================] - 89s 11s/step - loss: 1.0987 - accuracy: 0.3167 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 12/30
# 8/8 [==============================] - 86s 10s/step - loss: 1.0987 - accuracy: 0.3250 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 13/30
# 8/8 [==============================] - 81s 10s/step - loss: 2.0954 - accuracy: 0.3208 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 14/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 15/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0987 - accuracy: 0.3000 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 16/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0987 - accuracy: 0.3042 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 17/30
# 8/8 [==============================] - 86s 11s/step - loss: 1.0986 - accuracy: 0.3250 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 18/30
# 8/8 [==============================] - 85s 11s/step - loss: 104.7896 - accuracy: 0.2792 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 19/30
# 8/8 [==============================] - 89s 11s/step - loss: 1.0987 - accuracy: 0.3083 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 20/30
# 8/8 [==============================] - 87s 11s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 21/30
# 8/8 [==============================] - 75s 10s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 22/30
# 8/8 [==============================] - 83s 10s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 23/30
# 8/8 [==============================] - 85s 10s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 24/30
# 8/8 [==============================] - 86s 10s/step - loss: 1.0988 - accuracy: 0.3083 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 25/30
# 8/8 [==============================] - 81s 10s/step - loss: 1.0987 - accuracy: 0.2875 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 26/30
# 8/8 [==============================] - 82s 10s/step - loss: 1.0987 - accuracy: 0.3083 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 27/30
# 8/8 [==============================] - 81s 10s/step - loss: 1.0987 - accuracy: 0.3125 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 28/30
# 8/8 [==============================] - 83s 10s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 29/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 30/30
# 8/8 [==============================] - 81s 11s/step - loss: 1.0988 - accuracy: 0.2833 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 1/30
# 8/8 [==============================] - 87s 10s/step - loss: nan - accuracy: 0.3083 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 81s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/30
# 8/8 [==============================] - 83s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/30
# 8/8 [==============================] - 82s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/30
# 8/8 [==============================] - 87s 11s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 6/30
# 8/8 [==============================] - 80s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 7/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 8/30
# 8/8 [==============================] - 78s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 9/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 10/30
# 8/8 [==============================] - 78s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 11/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 12/30
# 8/8 [==============================] - 78s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 13/30
# 8/8 [==============================] - 78s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 14/30
# 8/8 [==============================] - 78s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 15/30
# 8/8 [==============================] - 80s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 16/30
# 8/8 [==============================] - 78s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 17/30
# 8/8 [==============================] - 77s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 18/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 19/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 20/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 21/30
# ...
# Epoch 5/10
# 8/8 [==============================] - 78s 10s/step - loss: 1.3239 - accuracy: 0.3333 - val_loss: 1.1023 - val_accuracy: 0.3500
# Epoch 6/10
# 8/8 [==============================] - 78s 10s/step - loss: 1.0945 - accuracy: 0.3500 - val_loss: 1.0896 - val_accuracy: 0.4000
# Epoch 7/10
# 8/8 [==============================] - 78s 9s/step - loss: 1.0809 - accuracy: 0.4167 - val_loss: 1.1131 - val_accuracy: 0.3000
# Epoch 8/10
# 8/8 [==============================] - 78s 10s/step - loss: 1.0863 - accuracy: 0.3667 - val_loss: 1.1028 - val_accuracy: 0.3333
# Epoch 9/10
# 8/8 [==============================] - 79s 10s/step - loss: 1.0832 - accuracy: 0.4208 - val_loss: 1.1133 - val_accuracy: 0.2833
# Epoch 10/10
# 8/8 [==============================] - 78s 10s/step - loss: 1.0656 - accuracy: 0.4542 - val_loss: 1.0884 - val_accuracy: 0.3667
# Epoch 1/10
# 8/8 [==============================] - 83s 10s/step - loss: 17728.0762 - accuracy: 0.3375 - val_loss: 1.1451 - val_accuracy: 0.3333
# Epoch 2/10
# 8/8 [==============================] - 78s 10s/step - loss: 3.4932 - accuracy: 0.3583 - val_loss: 1.9790 - val_accuracy: 0.3333
# Epoch 3/10
# 8/8 [==============================] - 80s 10s/step - loss: 2.5965 - accuracy: 0.3500 - val_loss: 1.3931 - val_accuracy: 0.3333
# Epoch 4/10
# 8/8 [==============================] - 79s 10s/step - loss: 3.2458 - accuracy: 0.4292 - val_loss: 1.1252 - val_accuracy: 0.3333
# Epoch 5/10
# 8/8 [==============================] - 78s 10s/step - loss: 7.9715 - accuracy: 0.3292 - val_loss: 2.9208 - val_accuracy: 0.3333
# Epoch 6/10
# 8/8 [==============================] - 79s 10s/step - loss: 6.7740 - accuracy: 0.3333 - val_loss: 1.0853 - val_accuracy: 0.3167
# Epoch 7/10
# 8/8 [==============================] - 77s 9s/step - loss: 15.7184 - accuracy: 0.2875 - val_loss: 1.0717 - val_accuracy: 0.4500
# Epoch 8/10
# 8/8 [==============================] - 77s 10s/step - loss: 1.0766 - accuracy: 0.4417 - val_loss: 1.0615 - val_accuracy: 0.3667
# Epoch 9/10
# 8/8 [==============================] - 78s 10s/step - loss: 1.0501 - accuracy: 0.4625 - val_loss: 1.2000 - val_accuracy: 0.3833
# Epoch 10/10
# 8/8 [==============================] - 78s 10s/step - loss: 65.0158 - accuracy: 0.3542 - val_loss: 80.1821 - val_accuracy: 0.3333
# Epoch 1/10
# 8/8 [==============================] - 78s 10s/step - loss: nan - accuracy: 0.3042 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/10
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/10
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/10
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/10
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 6/10
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 7/10
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 8/10
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 9/10
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 10/10
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 1/30
# 8/8 [==============================] - 86s 10s/step - loss: 1152.9310 - accuracy: 0.3208 - val_loss: 2.6656 - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 81s 10s/step - loss: 2.3352 - accuracy: 0.3125 - val_loss: 1.0889 - val_accuracy: 0.3500
# Epoch 3/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0986 - accuracy: 0.3958 - val_loss: 1.0954 - val_accuracy: 0.4167
# Epoch 4/30
# 8/8 [==============================] - 82s 10s/step - loss: 1.0849 - accuracy: 0.4292 - val_loss: 1.0593 - val_accuracy: 0.4333
# Epoch 5/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0723 - accuracy: 0.4125 - val_loss: 1.0155 - val_accuracy: 0.4833
# Epoch 6/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.1242 - accuracy: 0.3833 - val_loss: 1.0982 - val_accuracy: 0.3833
# Epoch 7/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0969 - accuracy: 0.3875 - val_loss: 1.0897 - val_accuracy: 0.4167
# Epoch 8/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.1115 - accuracy: 0.4292 - val_loss: 1.0896 - val_accuracy: 0.4000
# Epoch 9/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0961 - accuracy: 0.3708 - val_loss: 1.0985 - val_accuracy: 0.3667
# Epoch 10/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.1602 - accuracy: 0.4333 - val_loss: 1.1408 - val_accuracy: 0.3333
# Epoch 11/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0742 - accuracy: 0.4125 - val_loss: 1.1050 - val_accuracy: 0.3500
# Epoch 12/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0841 - accuracy: 0.3792 - val_loss: 1.0869 - val_accuracy: 0.3167
# Epoch 13/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0811 - accuracy: 0.4042 - val_loss: 1.0970 - val_accuracy: 0.3000
# Epoch 14/30
# 8/8 [==============================] - 80s 11s/step - loss: 1.0496 - accuracy: 0.4333 - val_loss: 1.1115 - val_accuracy: 0.3000
# Epoch 15/30
# 8/8 [==============================] - 81s 10s/step - loss: 1.0380 - accuracy: 0.4875 - val_loss: 1.1318 - val_accuracy: 0.3333
# Epoch 16/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0789 - accuracy: 0.4167 - val_loss: 1.0961 - val_accuracy: 0.3333
# Epoch 17/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0424 - accuracy: 0.4375 - val_loss: 1.1780 - val_accuracy: 0.3500
# Epoch 18/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0650 - accuracy: 0.4667 - val_loss: 1.1064 - val_accuracy: 0.3167
# Epoch 19/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0630 - accuracy: 0.4167 - val_loss: 1.0840 - val_accuracy: 0.3667
# Epoch 20/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0533 - accuracy: 0.4125 - val_loss: 1.1016 - val_accuracy: 0.3333
# Epoch 21/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0535 - accuracy: 0.4375 - val_loss: 1.1423 - val_accuracy: 0.3500
# Epoch 22/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0374 - accuracy: 0.4417 - val_loss: 1.0900 - val_accuracy: 0.3500
# Epoch 23/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0360 - accuracy: 0.4458 - val_loss: 1.0887 - val_accuracy: 0.4000
# Epoch 24/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0522 - accuracy: 0.4375 - val_loss: 1.1390 - val_accuracy: 0.3667
# Epoch 25/30
# 8/8 [==============================] - 81s 10s/step - loss: 1.0455 - accuracy: 0.4833 - val_loss: 1.1568 - val_accuracy: 0.4333
# Epoch 26/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0866 - accuracy: 0.4167 - val_loss: 1.0972 - val_accuracy: 0.4167
# Epoch 27/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0382 - accuracy: 0.4625 - val_loss: 1.3174 - val_accuracy: 0.4167
# Epoch 28/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.1228 - accuracy: 0.3792 - val_loss: 1.1121 - val_accuracy: 0.3167
# Epoch 29/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0915 - accuracy: 0.3667 - val_loss: 1.1075 - val_accuracy: 0.3167
# Epoch 30/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.0934 - accuracy: 0.3583 - val_loss: 1.1039 - val_accuracy: 0.3833
# Epoch 1/30
# 8/8 [==============================] - 81s 10s/step - loss: 6540.6284 - accuracy: 0.3542 - val_loss: 1.1346 - val_accuracy: 0.3500
# Epoch 2/30
# 8/8 [==============================] - 79s 10s/step - loss: 12.3478 - accuracy: 0.2958 - val_loss: 1.4440 - val_accuracy: 0.3333
# Epoch 3/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.1611 - accuracy: 0.3917 - val_loss: 1.0857 - val_accuracy: 0.4000
# Epoch 4/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.0913 - accuracy: 0.4042 - val_loss: 1.4808 - val_accuracy: 0.3333
# Epoch 5/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.5290 - accuracy: 0.3875 - val_loss: 1.1204 - val_accuracy: 0.4667
# Epoch 6/30
# 8/8 [==============================] - 79s 10s/step - loss: 3.2955 - accuracy: 0.3875 - val_loss: 13.4678 - val_accuracy: 0.3333
# Epoch 7/30
# 8/8 [==============================] - 81s 10s/step - loss: 6.9993 - accuracy: 0.4250 - val_loss: 1.1042 - val_accuracy: 0.4500
# Epoch 8/30
# 8/8 [==============================] - 78s 10s/step - loss: 1.0334 - accuracy: 0.4833 - val_loss: 3.2199 - val_accuracy: 0.3500
# Epoch 9/30
# 8/8 [==============================] - 78s 10s/step - loss: 17.5607 - accuracy: 0.3417 - val_loss: 1.1044 - val_accuracy: 0.3667
# Epoch 10/30
# 8/8 [==============================] - 77s 9s/step - loss: 1.7508 - accuracy: 0.3708 - val_loss: 5.9947 - val_accuracy: 0.5333
# Epoch 11/30
# 8/8 [==============================] - 78s 9s/step - loss: 7.0982 - accuracy: 0.3833 - val_loss: 6.9373 - val_accuracy: 0.3333
# Epoch 12/30
# 8/8 [==============================] - 78s 10s/step - loss: 7.3653 - accuracy: 0.3292 - val_loss: 1.2475 - val_accuracy: 0.3500
# Epoch 13/30
# 8/8 [==============================] - 77s 9s/step - loss: 1.2734 - accuracy: 0.4333 - val_loss: 1.1454 - val_accuracy: 0.4500
# Epoch 14/30
# 8/8 [==============================] - 77s 9s/step - loss: 1.0598 - accuracy: 0.4500 - val_loss: 1.0656 - val_accuracy: 0.4000
# Epoch 15/30
# 8/8 [==============================] - 77s 9s/step - loss: 1.0782 - accuracy: 0.4292 - val_loss: 2.8657 - val_accuracy: 0.3500
# Epoch 16/30
# 8/8 [==============================] - 77s 9s/step - loss: 29.0147 - accuracy: 0.3667 - val_loss: 1.2374 - val_accuracy: 0.3667
# Epoch 17/30
# 8/8 [==============================] - 77s 9s/step - loss: 1.0593 - accuracy: 0.4667 - val_loss: 1.1378 - val_accuracy: 0.5167
# Epoch 18/30
# 8/8 [==============================] - 77s 9s/step - loss: 0.9935 - accuracy: 0.5375 - val_loss: 0.9939 - val_accuracy: 0.5833
# Epoch 19/30
# 8/8 [==============================] - 80s 10s/step - loss: 1.1541 - accuracy: 0.5042 - val_loss: 1.3548 - val_accuracy: 0.4333
# Epoch 20/30
# 8/8 [==============================] - 81s 11s/step - loss: 1.4241 - accuracy: 0.4583 - val_loss: 1.1767 - val_accuracy: 0.3833
# Epoch 21/30
# 8/8 [==============================] - 77s 9s/step - loss: 0.9800 - accuracy: 0.5125 - val_loss: 1.0519 - val_accuracy: 0.5000
# Epoch 22/30
# 8/8 [==============================] - 77s 9s/step - loss: 1.4398 - accuracy: 0.4750 - val_loss: 1.0016 - val_accuracy: 0.5167
# Epoch 23/30
# 8/8 [==============================] - 77s 9s/step - loss: 1.1016 - accuracy: 0.5167 - val_loss: 1.1143 - val_accuracy: 0.4667
# Epoch 24/30
# 8/8 [==============================] - 74s 9s/step - loss: 3.3445 - accuracy: 0.4542 - val_loss: 0.9382 - val_accuracy: 0.5333
# Epoch 25/30
# 8/8 [==============================] - 76s 10s/step - loss: 0.9965 - accuracy: 0.4875 - val_loss: 1.0217 - val_accuracy: 0.4500
# Epoch 26/30
# 8/8 [==============================] - 79s 10s/step - loss: 1.4024 - accuracy: 0.4625 - val_loss: 0.9531 - val_accuracy: 0.5333
# Epoch 27/30
# 8/8 [==============================] - 77s 10s/step - loss: 1.0384 - accuracy: 0.4458 - val_loss: 1.0514 - val_accuracy: 0.4333
# Epoch 28/30
# 8/8 [==============================] - 77s 10s/step - loss: 1.0638 - accuracy: 0.5208 - val_loss: 0.9967 - val_accuracy: 0.5000
# Epoch 29/30
# 8/8 [==============================] - 78s 9s/step - loss: 0.9738 - accuracy: 0.5208 - val_loss: 1.4853 - val_accuracy: 0.3833
# Epoch 30/30
# 8/8 [==============================] - 78s 10s/step - loss: 2.8044 - accuracy: 0.3542 - val_loss: 1.0934 - val_accuracy: 0.4000
# Epoch 1/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3000 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/30
# 8/8 [==============================] - 74s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/30
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/30
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/30
# 8/8 [==============================] - 77s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 6/30
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 7/30
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 8/30
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 9/30
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 10/30
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 11/30
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 12/30
# 8/8 [==============================] - 77s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 13/30
# 8/8 [==============================] - 77s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 14/30
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 15/30
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 16/30
# 8/8 [==============================] - 76s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 17/30
# 8/8 [==============================] - 75s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 18/30
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 19/30
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 20/30
# 8/8 [==============================] - 75s 9s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 21/30
# 8/8 [==============================] - 81s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 22/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 23/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 24/30
# 8/8 [==============================] - 80s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 25/30
# 8/8 [==============================] - 78s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 26/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 27/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 28/30
# 8/8 [==============================] - 78s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 29/30
# 8/8 [==============================] - 78s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 30/30
# 8/8 [==============================] - 79s 10s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333

# %%
hyper_performance = pd.DataFrame(performance_list, columns=['Modele', 'filter_factor', \
                'num_units', 'num_epoch', 'optimizer', 'loss', 'accuracy', 'duration(s)'])
hyper_performance.to_csv('hyper_performance.csv')

# %% [markdown]
# # 4.  Transfer learning

# %% [markdown]
# ## 4.1 Chargement de modèle pré entrainé

# %% [raw]
# on utilise VGG avec Imagenet qui est la plus grande base d'images publique avec des millions d'images, y compris des animeaux

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models

# Chemin vers le dossier contenant les images du Stanford Dogs Dataset
data_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/Images"

# Charger le modèle pré-entraîné VGG16 sans la dernière couche (inclut_top=False)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %% [markdown]
# ## 4.2   Stratégie de transfer learning

# %% [raw]
# On choisit la stratégie d'extraction de features, car les animaux sont bien entrainés dans VGG avec imagenet

# %%
# Geler les couches du modèle pré-entraîné
for layer in base_model.layers:
    layer.trainable = False

# Ajouter de couches dense pour la classification des races de chiens
model_tl1 = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3, activation='softmax')  # 3 classes de races de chiens notre subset
])

# Compiler le modèle
model_tl1.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Afficher un résumé du modèle
model_tl1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 21,138,243
# Trainable params: 6,423,555
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## 4.3 entrainement de modèle avec subset

# %% [raw]
# on utilise les générateurs des sous ensemble d'images d'entraînement et de validation préparés au début

# %%
hist=model_tl1.fit_generator(generator = subset_train_images,
                         epochs=10,
                         validation_data=subset_validation_images)
model_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/models"

model_path = os.path.join(model_dir, "model_tl1_sub.h5")
model_tl1.save(model_path)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 51s 6s/step - loss: 0.2035 - accuracy: 0.9167 - val_loss: 0.4836 - val_accuracy: 0.8333
# Epoch 2/10
# 8/8 [==============================] - 49s 6s/step - loss: 0.1722 - accuracy: 0.9292 - val_loss: 0.3650 - val_accuracy: 0.8667
# Epoch 3/10
# 8/8 [==============================] - 51s 6s/step - loss: 0.1672 - accuracy: 0.9458 - val_loss: 0.4527 - val_accuracy: 0.8500
# Epoch 4/10
# 8/8 [==============================] - 48s 6s/step - loss: 0.1680 - accuracy: 0.9375 - val_loss: 0.3919 - val_accuracy: 0.8500
# Epoch 5/10
# 8/8 [==============================] - 48s 6s/step - loss: 0.1529 - accuracy: 0.9542 - val_loss: 0.3746 - val_accuracy: 0.8667
# Epoch 6/10
# 8/8 [==============================] - 47s 6s/step - loss: 0.1424 - accuracy: 0.9417 - val_loss: 0.3866 - val_accuracy: 0.8667
# Epoch 7/10
# 8/8 [==============================] - 51s 6s/step - loss: 0.2484 - accuracy: 0.8958 - val_loss: 0.3660 - val_accuracy: 0.8667
# Epoch 8/10
# 8/8 [==============================] - 47s 6s/step - loss: 0.1367 - accuracy: 0.9500 - val_loss: 0.3084 - val_accuracy: 0.8833
# Epoch 9/10
# 8/8 [==============================] - 48s 6s/step - loss: 0.1285 - accuracy: 0.9667 - val_loss: 0.3451 - val_accuracy: 0.8667
# Epoch 10/10
# 8/8 [==============================] - 48s 6s/step - loss: 0.1960 - accuracy: 0.9208 - val_loss: 0.3711 - val_accuracy: 0.8833

# %%
plot_model_history(hist, start_epoch=1)

# %%
# prediction des classes dans le subset de validation
model_path = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/models/model_tl1_sub.h5"
model_tl1 = load_model(model_path)

y_pred_val =  model_tl1.predict_generator(subset_validation_images)
predicted_class_indices_val=np.argmax(y_pred_val,axis=1)

labels = (subset_train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
# Out:
# WARNING:tensorflow:5 out of the last 67 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001609CAAADC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# Culcule la matrice de confusion pour les 3 classses

y_true = subset_validation_images.classes
conf_matrix = confusion_matrix(y_true, predicted_class_indices_val)

# Create a list of class names (assuming the order of classes in the dictionary)
class_names = list(labels.values())

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# prediction des classes dans le subset de tests
y_pred =  model_tl1.predict(subset_test_images)

predicted_class_indices=np.argmax(y_pred,axis=1)

labels = (subset_train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

filenames=subset_test_images.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})
results.to_csv("results_tl.csv",index=False)
# Out:
# 60/60 [==============================] - 9s 148ms/step

# %% [markdown]
# ## 4.4. Entrainement de modèle avec full set

# %% [raw]
# on utilise les générateurs de la totalité d'images d'entraînement et de validation préparés au début

# %%
# Ajouter de couches dense pour la classification des races de chiens
model_tl2 = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(120, activation='softmax')  # 120 classes de races 
])

# Compiler le modèle
model_tl2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Afficher un résumé du modèle
model_tl2.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_26 (Flatten)        (None, 25088)             0
#
#  dense_52 (Dense)            (None, 256)               6422784
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_53 (Dense)            (None, 120)               30840
#
# =================================================================
# Total params: 21,168,312
# Trainable params: 6,453,624
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
hist=model_tl2.fit_generator(generator = train_images,
                         epochs=10,
                         validation_data=validation_images)
model_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/models"

model_path = os.path.join(model_dir, "model_tl2_full.h5")
model.save(model_path)
# Out:
# Epoch 1/10
# 514/514 [==============================] - 3143s 6s/step - loss: 5.6685 - accuracy: 0.0116 - val_loss: 4.7855 - val_accuracy: 0.0125
# Epoch 2/10
# 514/514 [==============================] - 2748s 5s/step - loss: 4.7856 - accuracy: 0.0122 - val_loss: 4.7832 - val_accuracy: 0.0123
# Epoch 3/10
# 514/514 [==============================] - 2845s 6s/step - loss: 4.7878 - accuracy: 0.0121 - val_loss: 4.7820 - val_accuracy: 0.0123
# Epoch 4/10
# 514/514 [==============================] - 2887s 6s/step - loss: 4.7818 - accuracy: 0.0119 - val_loss: 4.8399 - val_accuracy: 0.0123
# Epoch 5/10
# 514/514 [==============================] - 3174s 6s/step - loss: 4.7845 - accuracy: 0.0122 - val_loss: 4.7794 - val_accuracy: 0.0123
# Epoch 6/10
# 514/514 [==============================] - 2971s 6s/step - loss: 4.7802 - accuracy: 0.0122 - val_loss: 4.7794 - val_accuracy: 0.0123
# Epoch 7/10
# 514/514 [==============================] - 2995s 6s/step - loss: 4.7831 - accuracy: 0.0122 - val_loss: 4.7793 - val_accuracy: 0.0123
# Epoch 8/10
# 514/514 [==============================] - 2727s 5s/step - loss: 4.7902 - accuracy: 0.0123 - val_loss: 4.7792 - val_accuracy: 0.0123
# Epoch 9/10
# 514/514 [==============================] - 2735s 5s/step - loss: 4.7831 - accuracy: 0.0122 - val_loss: 4.7792 - val_accuracy: 0.0123
# Epoch 10/10
# 514/514 [==============================] - 2696s 5s/step - loss: 4.7807 - accuracy: 0.0122 - val_loss: 4.7787 - val_accuracy: 0.0123

# %%
plot_model_history(hist, start_epoch=1)

# %%
# Ajouter de couches dense pour la classification des races de chiens
model_tl3 = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(1200, activation='relu'),
#    layers.Dropout(0.5),
    layers.Dense(120, activation='softmax')  # 120 classes de races 
])

# Compiler le modèle
model_tl3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Afficher un résumé du modèle
model_tl3.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_27 (Flatten)        (None, 25088)             0
#
#  dense_54 (Dense)            (None, 1200)              30106800
#
#  dense_55 (Dense)            (None, 120)               144120
#
# =================================================================
# Total params: 44,965,608
# Trainable params: 44,965,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist3=model_tl3.fit_generator(generator = train_images,
                         epochs=5,
                         validation_data=validation_images)
model_dir = "C:/Users/utilisateur/OneDrive/Document/Trading/ML/Projet6/data/images/models"

model_path = os.path.join(model_dir, "model_tl3_full.h5")
model.save(model_path)
# Out:
# Epoch 1/5
# 514/514 [==============================] - 8994s 17s/step - loss: 5.4960 - accuracy: 0.0106 - val_loss: 4.7776 - val_accuracy: 0.0118
# Epoch 2/5
# 514/514 [==============================] - 8507s 17s/step - loss: 4.7822 - accuracy: 0.0116 - val_loss: 4.7797 - val_accuracy: 0.0123
# Epoch 3/5
# 514/514 [==============================] - 8871s 17s/step - loss: 4.7821 - accuracy: 0.0116 - val_loss: 4.7795 - val_accuracy: 0.0123
# Epoch 4/5
# 514/514 [==============================] - 8710s 17s/step - loss: 4.7815 - accuracy: 0.0118 - val_loss: 4.7793 - val_accuracy: 0.0123
# Epoch 5/5
# 514/514 [==============================] - 7808s 15s/step - loss: 4.7813 - accuracy: 0.0122 - val_loss: 4.7792 - val_accuracy: 0.0123

# %%
plot_model_history(hist3, start_epoch=1)

# %% [raw]
# Annex: programme pour afficher en graphique les combinaison des hyperparamètres

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given performance data
performance_data = {
    'optimizer': ['adam', 'adam', 'adam', 'adam', 'adam', 'adam', 'adam', 'adam', 'rmsprop', 'rmsprop', 'rmsprop', 'rmsprop', 'rmsprop', 'rmsprop', 'rmsprop', 'rmsprop'],
    'filter_factor': [1, 1, 1, 1, 3, 3, 3, 3, 1, 1, 1, 1, 3, 3, 3, 3],
    'num_units': [64, 64, 256, 256, 64, 64, 256, 256, 64, 64, 256, 256, 64, 64, 256, 256],
    'num_epochs': [10, 30, 10, 30, 10, 30, 10, 30, 10, 30, 10, 30, 10, 30, 10, 30],
    'loss': [1.1564, 1.0266, 1.053, 1.1361, 1.0853, 1.0986, 1.0884, 1.1039, 1.0326, 1.0662, 20.8895, 1.1096, 1.0912, 1.0986, 80.1821, 1.0934],
    'accuracy': [0.3667, 0.45, 0.4333, 0.4167, 0.4, 0.3333, 0.3667, 0.3833, 0.4333, 0.4833, 0.3333, 0.55, 0.4, 0.3333, 0.3333, 0.3333],
    'duration': [294, 870, 300, 911, 812, 2477, 789, 2392, 298, 832, 306, 942, 874, 2497, 788, 2342]
}

# Extract unique values for each parameter
optimizers = np.unique(performance_data['optimizer'])
filter_factors = np.unique(performance_data['filter_factor'])
num_units = np.unique(performance_data['num_units'])
num_epochs = np.unique(performance_data['num_epochs'])

# Create a figure for accuracy
fig_accuracy, ax_accuracy = plt.subplots(figsize=(12, 6))
ax_accuracy.set_xlabel('Number of Epochs')
ax_accuracy.set_ylabel('Accuracy')
ax_accuracy.set_title('Accuracy vs. Number of Epochs')

# Create a figure for loss
fig_loss, ax_loss = plt.subplots(figsize=(12, 6))
ax_loss.set_xlabel('Number of Epochs')
ax_loss.set_ylabel('Loss')
ax_loss.set_title('Loss vs. Number of Epochs')

for optimizer in optimizers:
    for filter_factor in filter_factors:
        for num_unit in num_units:
            accuracy_vals = []
            loss_vals = []
            num_epochs_vals = []
            
            for index, opt in enumerate(performance_data['optimizer']):
                factor = performance_data['filter_factor'][index]
                unit = performance_data['num_units'][index]
                loss = performance_data['loss'][index]
                
                if opt == optimizer and factor == filter_factor and unit == num_unit:
                    accuracy_vals.append(performance_data['accuracy'][index])
                    num_epochs_vals.append(performance_data['num_epochs'][index])
                    
                    if loss <= 20:  # Discard loss values greater than 20
                        loss_vals.append(loss)
            
            if len(accuracy_vals) > 0:
                ax_accuracy.plot(num_epochs_vals, accuracy_vals, label=f"{optimizer}, filter={filter_factor}, units={num_unit}")
            
            if len(loss_vals) > 0:
                ax_loss.plot(num_epochs_vals, loss_vals, label=f"{optimizer}, filter={filter_factor}, units={num_unit}")

# Show legends for both figures
ax_accuracy.legend()
ax_loss.legend()

# Show the figures
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20476\219913352.py in <module>
#      54
#      55             if len(loss_vals) > 0:
# ---> 56                 ax_loss.plot(num_epochs_vals, loss_vals, label=f"{optimizer}, filter={filter_factor}, units={num_unit}")
#      57
#      58 # Show legends for both figures
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     502
#     503         if x.shape[0] != y.shape[0]:
# --> 504             raise ValueError(f"x and y must have same first dimension, but "
#     505                              f"have shapes {x.shape} and {y.shape}")
#     506         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (2,) and (1,)
